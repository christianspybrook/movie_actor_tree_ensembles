# %%
raise SystemExit("Stop right there!")

# %%
import requests
import json
import pandas as pd
from IPython.display import clear_output
from time import sleep
import numpy as np

# %%
# retrieve my TMDb key
local_file = 'tmdb_key.txt'
with open(local_file, 'r') as api_file:
    my_key = api_file.read().rstrip('\r\n')
    api_file.close()

# %%
# set first part of URL for every request
base_url = 'https://api.themoviedb.org/3/'

# %%
def make_request(_id, prior_attempts=0):
    """Makes request for movie object in TMDb database and returns it as JSON"""
    if prior_attempts == 3:
        return {}
    url = base_url + 'movie/' + str(_id) + '?api_key=' + my_key + '&append_to_response=credits,reviews'
    response = requests.get(url)
    # entry not found
    if response.status_code == 404:
        return {}
    # exceed rate limit
    if response.status_code == 429:
        sleep(10)
        return make_request(_id=_id)
    # success
    if response.status_code == 200:
        return response.json()
    else:
        sleep(1)
        return make_request(_id=_id, prior_attempts=prior_attempts + 1)

# %%
def get_movies(num):
    """Makes 100,000 requests for movie objects in TMDb database and stores them in a list of JSON's"""
    movies_list = []
    for val in range(num - 99999, num + 1):
        print(val)
        clear_output(wait=True)
        movies_list.append(make_request(_id=val))
    return movies_list

# %%
df = pd.DataFrame(get_movies(num=100000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  70692 non-null  object
#  1   backdrop_path          26073 non-null  object
#  2   belongs_to_collection  6440 non-null   object
#  3   budget                 70692 non-null  float64
#  4   genres                 70692 non-null  object
#  5   homepage               67860 non-null  object
#  6   id                     70692 non-null  float64
#  7   imdb_id                70692 non-null  object
#  8   original_language      70692 non-null  object
#  9   original_title         70692 non-null  object
#  10  overview               70692 non-null  object
#  11  popularity             70692 non-null  float64
#  12  poster_path            48241 non-null  object
#  13  production_companies   70692 non-null  object
#  14  production_countries   70692 non-null  object
#  15  release_date           70692 non-null  object
#  16  revenue                70692 non-null  float64
#  17  runtime                69733 non-null  float64
#  18  spoken_languages       70692 non-null  object
#  19  status                 70692 non-null  object
#  20  tagline                70692 non-null  object
#  21  title                  70692 non-null  object
#  22  video                  70692 non-null  object
#  23  vote_average           70692 non-null  float64
#  24  vote_count             70692 non-null  float64
#  25  credits                70692 non-null  object
#  26  reviews                70692 non-null  object
# dtypes: float64(7), object(20)
# memory usage: 20.6+ MB

# %%
#df.to_json('tmdb_movies_100k.json')

# %%
df_100k = pd.read_json('tmdb_movies_100k.json')
df_100k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  70692 non-null  float64
#  1   backdrop_path          26073 non-null  object
#  2   belongs_to_collection  6440 non-null   object
#  3   budget                 70692 non-null  float64
#  4   genres                 70692 non-null  object
#  5   homepage               67860 non-null  object
#  6   id                     70692 non-null  float64
#  7   imdb_id                70692 non-null  object
#  8   original_language      70692 non-null  object
#  9   original_title         70692 non-null  object
#  10  overview               70692 non-null  object
#  11  popularity             70692 non-null  float64
#  12  poster_path            48241 non-null  object
#  13  production_companies   70692 non-null  object
#  14  production_countries   70692 non-null  object
#  15  release_date           70692 non-null  object
#  16  revenue                70692 non-null  float64
#  17  runtime                69733 non-null  float64
#  18  spoken_languages       70692 non-null  object
#  19  status                 70692 non-null  object
#  20  tagline                70692 non-null  object
#  21  title                  70692 non-null  object
#  22  video                  70692 non-null  float64
#  23  vote_average           70692 non-null  float64
#  24  vote_count             70692 non-null  float64
#  25  credits                70692 non-null  object
#  26  reviews                70692 non-null  object
# dtypes: float64(9), object(18)
# memory usage: 21.4+ MB

# %%
df_100k.head().transpose()
# Out:
#                           0  \
# adult                   NaN
# backdrop_path          None
# belongs_to_collection  None
# budget                  NaN
# genres                 None
# homepage               None
# id                      NaN
# imdb_id                None
# original_language      None
# original_title         None
# overview               None
# popularity              NaN
# poster_path            None
# production_companies   None
# production_countries   None
# release_date           None
# revenue                 NaN
# runtime                 NaN
# spoken_languages       None
# status                 None
# tagline                None
# title                  None
# video                   NaN
# vote_average            NaN
# vote_count              NaN
# credits                None
# reviews                None
#
#                                                                        1  \
# adult                                                                  0
# backdrop_path                           /kpuTCMw3v2AuKjqGS7383uWbc8V.jpg
# belongs_to_collection                                               None
# budget                                                                 0
# genres                 [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# homepage
# id                                                                     2
# imdb_id                                                        tt0094675
# original_language                                                     fi
# original_title                                                     Ariel
# overview               Taisto Kasurinen is a Finnish coal miner whose...
# popularity                                                         8.098
# poster_path                             /ojDg0PGvs6R9xYFodRct2kdI6wC.jpg
# production_companies   [{'id': 2303, 'logo_path': None, 'name': 'Vill...
# production_countries           [{'iso_3166_1': 'FI', 'name': 'Finland'}]
# release_date                                                  1988-10-21
# revenue                                                                0
# runtime                                                               73
# spoken_languages       [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...
# status                                                          Released
# tagline
# title                                                              Ariel
# video                                                                  0
# vote_average                                                         6.8
# vote_count                                                           100
# credits                {'cast': [{'cast_id': 3, 'character': 'Taisto ...
# reviews                {'page': 1, 'results': [], 'total_pages': 0, '...
#
#                                                                        2  \
# adult                                                                  0
# backdrop_path                           /jMmHFm0TcjiN9QDICXY2tJcQsDl.jpg
# belongs_to_collection                                               None
# budget                                                                 0
# genres                 [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# homepage
# id                                                                     3
# imdb_id                                                        tt0092149
# original_language                                                     fi
# original_title                                      Varjoja paratiisissa
# overview               An episode in the life of Nikander, a garbage ...
# popularity                                                         7.568
# poster_path                             /nj01hspawPof0mJmlgfjuLyJuRN.jpg
# production_companies   [{'id': 2303, 'logo_path': None, 'name': 'Vill...
# production_countries           [{'iso_3166_1': 'FI', 'name': 'Finland'}]
# release_date                                                  1986-10-17
# revenue                                                                0
# runtime                                                               72
# spoken_languages       [{'iso_639_1': 'sv', 'name': 'svenska'}, {'iso...
# status                                                          Released
# tagline
# title                                                Shadows in Paradise
# video                                                                  0
# vote_average                                                         7.4
# vote_count                                                           106
# credits                {'cast': [{'cast_id': 5, 'character': 'Nikande...
# reviews                {'page': 1, 'results': [{'author': 'CRCulver',...
#
#                           3                                                  4
# adult                   NaN                                                  0
# backdrop_path          None                   /xvjGhJHsArVjCWXb5OARi0PiqvB.jpg
# belongs_to_collection  None                                               None
# budget                  NaN                                              4e+06
# genres                 None  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...
# homepage               None
# id                      NaN                                                  5
# imdb_id                None                                          tt0113101
# original_language      None                                                 en
# original_title         None                                         Four Rooms
# overview               None  It's Ted the Bellhop's first night on the job....
# popularity              NaN                                             13.532
# poster_path            None                   /xhU6hPDnk4s8iWWKoq4oEmNI600.jpg
# production_companies   None  [{'id': 14, 'logo_path': '/m6AHu84oZQxvq7n1rsv...
# production_countries   None  [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date           None                                         1995-12-09
# revenue                 NaN                                        4.25735e+06
# runtime                 NaN                                                 98
# spoken_languages       None           [{'iso_639_1': 'en', 'name': 'English'}]
# status                 None                                           Released
# tagline                None  Twelve outrageous guests. Four scandalous requ...
# title                  None                                         Four Rooms
# video                   NaN                                                  0
# vote_average            NaN                                                  6
# vote_count              NaN                                               1561
# credits                None  {'cast': [{'cast_id': 42, 'character': 'Ted th...
# reviews                None  {'page': 1, 'results': [], 'total_pages': 0, '...

# %%
df_100k.tail()
# Out:
#        adult                     backdrop_path belongs_to_collection  budget  \
# 99995    NaN                              None                  None     NaN
# 99996    0.0  /rOIclzR6CpSlgylNsm2gzUC8SyU.jpg                  None     0.0
# 99997    0.0                              None                  None     0.0
# 99998    0.0                              None                  None     0.0
# 99999    NaN                              None                  None     NaN
#
#                                                   genres homepage       id  \
# 99995                                               None     None      NaN
# 99996                      [{'id': 18, 'name': 'Drama'}]           99997.0
# 99997  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...           99998.0
# 99998  [{'id': 99, 'name': 'Documentary'}, {'id': 36,...           99999.0
# 99999                                               None     None      NaN
#
#          imdb_id original_language         original_title  ... runtime  \
# 99995       None              None                   None  ...     NaN
# 99996  tt0027196                en  West Point of the Air  ...    89.0
# 99997  tt0032130                en      Wings of the Navy  ...    89.0
# 99998  tt0156078                de  Der Sieg des Glaubens  ...    61.0
# 99999       None              None                   None  ...     NaN
#
#                                spoken_languages    status  \
# 99995                                      None      None
# 99996  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 99997  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 99998  [{'iso_639_1': 'de', 'name': 'Deutsch'}]  Released
# 99999                                      None      None
#
#                                                  tagline  \
# 99995                                               None
# 99996        Biggest Romantic Thrill Since "Hell Divers"
# 99997  FOR ALL THE WORLD TO WITNESS THAT AMERICA WILL...
# 99998
# 99999                                               None
#
#                        title video  vote_average  vote_count  \
# 99995                   None   NaN           NaN         NaN
# 99996  West Point of the Air   0.0           7.0         1.0
# 99997      Wings of the Navy   0.0           7.0         2.0
# 99998   Victory of the Faith   0.0           6.8         4.0
# 99999                   None   NaN           NaN         NaN
#
#                                                  credits  \
# 99995                                               None
# 99996  {'cast': [{'cast_id': 4, 'character': 'Sgt. 'B...
# 99997  {'cast': [{'cast_id': 3, 'character': 'Cass Ha...
# 99998  {'cast': [{'cast_id': 4, 'character': 'Himself...
# 99999                                               None
#
#                                                  reviews
# 99995                                               None
# 99996  {'page': 1, 'results': [], 'total_pages': 0, '...
# 99997  {'page': 1, 'results': [], 'total_pages': 0, '...
# 99998  {'page': 1, 'results': [], 'total_pages': 0, '...
# 99999                                               None
#
# [5 rows x 27 columns]

# %%
df = pd.DataFrame(get_movies(num=200000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  50946 non-null  object
#  1   backdrop_path          8936 non-null   object
#  2   belongs_to_collection  1868 non-null   object
#  3   budget                 50946 non-null  float64
#  4   genres                 50946 non-null  object
#  5   homepage               45528 non-null  object
#  6   id                     50946 non-null  float64
#  7   imdb_id                50946 non-null  object
#  8   original_language      50946 non-null  object
#  9   original_title         50946 non-null  object
#  10  overview               50946 non-null  object
#  11  popularity             50946 non-null  float64
#  12  poster_path            21841 non-null  object
#  13  production_companies   50946 non-null  object
#  14  production_countries   50946 non-null  object
#  15  release_date           50946 non-null  object
#  16  revenue                50946 non-null  float64
#  17  runtime                49429 non-null  float64
#  18  spoken_languages       50946 non-null  object
#  19  status                 50946 non-null  object
#  20  tagline                50946 non-null  object
#  21  title                  50946 non-null  object
#  22  video                  50946 non-null  object
#  23  vote_average           50946 non-null  float64
#  24  vote_count             50946 non-null  float64
#  25  credits                50946 non-null  object
#  26  reviews                50946 non-null  object
# dtypes: float64(7), object(20)
# memory usage: 20.6+ MB

# %%
#df.to_json('tmdb_movies_200k.json')

# %%
df_200k = pd.read_json('tmdb_movies_200k.json')
df_200k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  50946 non-null  float64
#  1   backdrop_path          8936 non-null   object
#  2   belongs_to_collection  1868 non-null   object
#  3   budget                 50946 non-null  float64
#  4   genres                 50946 non-null  object
#  5   homepage               45528 non-null  object
#  6   id                     50946 non-null  float64
#  7   imdb_id                50946 non-null  object
#  8   original_language      50946 non-null  object
#  9   original_title         50946 non-null  object
#  10  overview               50946 non-null  object
#  11  popularity             50946 non-null  float64
#  12  poster_path            21841 non-null  object
#  13  production_companies   50946 non-null  object
#  14  production_countries   50946 non-null  object
#  15  release_date           50946 non-null  object
#  16  revenue                50946 non-null  float64
#  17  runtime                49429 non-null  float64
#  18  spoken_languages       50946 non-null  object
#  19  status                 50946 non-null  object
#  20  tagline                50946 non-null  object
#  21  title                  50946 non-null  object
#  22  video                  50946 non-null  float64
#  23  vote_average           50946 non-null  float64
#  24  vote_count             50946 non-null  float64
#  25  credits                50946 non-null  object
#  26  reviews                50946 non-null  object
# dtypes: float64(9), object(18)
# memory usage: 21.4+ MB

# %%
df_200k.head().transpose()
# Out:
#                           0     1     2     3     4
# adult                   NaN   NaN   NaN   NaN   NaN
# backdrop_path          None  None  None  None  None
# belongs_to_collection  None  None  None  None  None
# budget                  NaN   NaN   NaN   NaN   NaN
# genres                 None  None  None  None  None
# homepage               None  None  None  None  None
# id                      NaN   NaN   NaN   NaN   NaN
# imdb_id                None  None  None  None  None
# original_language      None  None  None  None  None
# original_title         None  None  None  None  None
# overview               None  None  None  None  None
# popularity              NaN   NaN   NaN   NaN   NaN
# poster_path            None  None  None  None  None
# production_companies   None  None  None  None  None
# production_countries   None  None  None  None  None
# release_date           None  None  None  None  None
# revenue                 NaN   NaN   NaN   NaN   NaN
# runtime                 NaN   NaN   NaN   NaN   NaN
# spoken_languages       None  None  None  None  None
# status                 None  None  None  None  None
# tagline                None  None  None  None  None
# title                  None  None  None  None  None
# video                   NaN   NaN   NaN   NaN   NaN
# vote_average            NaN   NaN   NaN   NaN   NaN
# vote_count              NaN   NaN   NaN   NaN   NaN
# credits                None  None  None  None  None
# reviews                None  None  None  None  None

# %%
df_200k.tail()
# Out:
#        adult                     backdrop_path belongs_to_collection  budget  \
# 99995    NaN                              None                  None     NaN
# 99996    0.0                              None                  None     0.0
# 99997    NaN                              None                  None     NaN
# 99998    0.0  /d28wW9zp01Oibs09TQZkBOEjssc.jpg                  None     0.0
# 99999    0.0                              None                  None     0.0
#
#                                                   genres  \
# 99995                                               None
# 99996                      [{'id': 18, 'name': 'Drama'}]
# 99997                                               None
# 99998  [{'id': 10751, 'name': 'Family'}, {'id': 18, '...
# 99999                      [{'id': 18, 'name': 'Drama'}]
#
#                                          homepage        id    imdb_id  \
# 99995                                        None       NaN       None
# 99996                                              199997.0  tt2609468
# 99997                                        None       NaN       None
# 99998  http://www.thehousethatjackbuiltmovie.com/  199999.0  tt2190492
# 99999                                              200000.0  tt1920925
#
#       original_language             original_title  ... runtime  \
# 99995              None                       None  ...     NaN
# 99996                hi                   सोना Spa  ...   102.0
# 99997              None                       None  ...     NaN
# 99998                en  The House That Jack Built  ...    90.0
# 99999                en              Fish n' Chips  ...   102.0
#
#                                         spoken_languages    status  \
# 99995                                               None      None
# 99996  [{'iso_639_1': 'hi', 'name': 'हिन्दी'}, {'iso_...  Released
# 99997                                               None      None
# 99998           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 99999  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                            tagline                      title video  \
# 99995                         None                       None   NaN
# 99996  You Can Buy Your Sleep Here                   Sona Spa   0.0
# 99997                         None                       None   NaN
# 99998                               The House That Jack Built   0.0
# 99999                                           Fish n' Chips   0.0
#
#        vote_average  vote_count  \
# 99995           NaN         NaN
# 99996           2.7         3.0
# 99997           NaN         NaN
# 99998           5.3         4.0
# 99999           5.0         1.0
#
#                                                  credits  \
# 99995                                               None
# 99996  {'cast': [{'cast_id': 6, 'character': 'Baba', ...
# 99997                                               None
# 99998  {'cast': [{'cast_id': 4, 'character': 'Jack', ...
# 99999  {'cast': [], 'crew': [{'credit_id': '57b626759...
#
#                                                  reviews
# 99995                                               None
# 99996  {'page': 1, 'results': [], 'total_pages': 0, '...
# 99997                                               None
# 99998  {'page': 1, 'results': [], 'total_pages': 0, '...
# 99999  {'page': 1, 'results': [], 'total_pages': 0, '...
#
# [5 rows x 27 columns]

# %%
df = pd.DataFrame(get_movies(num=300000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  69297 non-null  object
#  1   backdrop_path          8467 non-null   object
#  2   belongs_to_collection  1461 non-null   object
#  3   budget                 69297 non-null  float64
#  4   genres                 69297 non-null  object
#  5   homepage               52921 non-null  object
#  6   id                     69297 non-null  float64
#  7   imdb_id                65044 non-null  object
#  8   original_language      69297 non-null  object
#  9   original_title         69297 non-null  object
#  10  overview               69297 non-null  object
#  11  popularity             69297 non-null  float64
#  12  poster_path            23897 non-null  object
#  13  production_companies   69297 non-null  object
#  14  production_countries   69297 non-null  object
#  15  release_date           69297 non-null  object
#  16  revenue                69297 non-null  float64
#  17  runtime                61219 non-null  float64
#  18  spoken_languages       69297 non-null  object
#  19  status                 69297 non-null  object
#  20  tagline                69297 non-null  object
#  21  title                  69297 non-null  object
#  22  video                  69297 non-null  object
#  23  vote_average           69297 non-null  float64
#  24  vote_count             69297 non-null  float64
#  25  credits                69297 non-null  object
#  26  reviews                69297 non-null  object
# dtypes: float64(7), object(20)
# memory usage: 20.6+ MB

# %%
#df.to_json('tmdb_movies_300k.json')

# %%
df_300k = pd.read_json('tmdb_movies_300k.json')
df_300k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  69297 non-null  float64
#  1   backdrop_path          8467 non-null   object
#  2   belongs_to_collection  1461 non-null   object
#  3   budget                 69297 non-null  float64
#  4   genres                 69297 non-null  object
#  5   homepage               52921 non-null  object
#  6   id                     69297 non-null  float64
#  7   imdb_id                65044 non-null  object
#  8   original_language      69297 non-null  object
#  9   original_title         69297 non-null  object
#  10  overview               69297 non-null  object
#  11  popularity             69297 non-null  float64
#  12  poster_path            23897 non-null  object
#  13  production_companies   69297 non-null  object
#  14  production_countries   69297 non-null  object
#  15  release_date           69297 non-null  object
#  16  revenue                69297 non-null  float64
#  17  runtime                61219 non-null  float64
#  18  spoken_languages       69297 non-null  object
#  19  status                 69297 non-null  object
#  20  tagline                69297 non-null  object
#  21  title                  69297 non-null  object
#  22  video                  69297 non-null  float64
#  23  vote_average           69297 non-null  float64
#  24  vote_count             69297 non-null  float64
#  25  credits                69297 non-null  object
#  26  reviews                69297 non-null  object
# dtypes: float64(9), object(18)
# memory usage: 21.4+ MB

# %%
df_300k.head().transpose()
# Out:
#                                                                        0  \
# adult                                                                  0
# backdrop_path                                                       None
# belongs_to_collection                                               None
# budget                                                                 0
# genres                               [{'id': 99, 'name': 'Documentary'}]
# homepage
# id                                                                200001
# imdb_id                                                        tt0856245
# original_language                                                     de
# original_title                     Nach Hollywood - Douglas Sirk erzählt
# overview               This 82-minute 1991 documentary by Eckhart Sch...
# popularity                                                           0.6
# poster_path                             /uVZiOccDAhDQULKukvRY0U8wlIw.jpg
# production_companies                                                  []
# production_countries           [{'iso_3166_1': 'DE', 'name': 'Germany'}]
# release_date                                                  1991-06-07
# revenue                                                                0
# runtime                                                               82
# spoken_languages                [{'iso_639_1': 'de', 'name': 'Deutsch'}]
# status                                                          Released
# tagline
# title                      From UFA to Hollywood: Douglas Sirk Remembers
# video                                                                  0
# vote_average                                                           6
# vote_count                                                             1
# credits                {'cast': [{'cast_id': 2, 'character': '', 'cre...
# reviews                {'page': 1, 'results': [], 'total_pages': 0, '...
#
#                                                                        1  \
# adult                                                                  0
# backdrop_path                                                       None
# belongs_to_collection                                               None
# budget                                                                 0
# genres                                     [{'id': 18, 'name': 'Drama'}]
# homepage                            http://www.imdb.com/title/tt0408295/
# id                                                                200002
# imdb_id                                                        tt0408295
# original_language                                                     fr
# original_title                               Une place parmi les vivants
# overview               A mediocre pulp novelist is approached by a st...
# popularity                                                         0.698
# poster_path                             /4vGtkyylemLzH2qScv9YIDiLhwh.jpg
# production_companies   [{'id': 94, 'logo_path': '/huC7HqorvUThGIrENrb...
# production_countries            [{'iso_3166_1': 'FR', 'name': 'France'}]
# release_date                                                  2003-01-01
# revenue                                                                0
# runtime                                                              103
# spoken_languages               [{'iso_639_1': 'fr', 'name': 'Français'}]
# status                                                          Released
# tagline
# title                                           A Place Among the Living
# video                                                                  0
# vote_average                                                         7.3
# vote_count                                                             2
# credits                {'cast': [{'cast_id': 1, 'character': 'Ernest ...
# reviews                {'page': 1, 'results': [], 'total_pages': 0, '...
#
#                           2     3  \
# adult                   NaN   NaN
# backdrop_path          None  None
# belongs_to_collection  None  None
# budget                  NaN   NaN
# genres                 None  None
# homepage               None  None
# id                      NaN   NaN
# imdb_id                None  None
# original_language      None  None
# original_title         None  None
# overview               None  None
# popularity              NaN   NaN
# poster_path            None  None
# production_companies   None  None
# production_countries   None  None
# release_date           None  None
# revenue                 NaN   NaN
# runtime                 NaN   NaN
# spoken_languages       None  None
# status                 None  None
# tagline                None  None
# title                  None  None
# video                   NaN   NaN
# vote_average            NaN   NaN
# vote_count              NaN   NaN
# credits                None  None
# reviews                None  None
#
#                                                                        4
# adult                                                                  0
# backdrop_path                                                       None
# belongs_to_collection                                               None
# budget                                                                 0
# genres                                                                []
# homepage               http://www.go-betweens.net/discography/2005str...
# id                                                                200005
# imdb_id
# original_language                                                     en
# original_title                               That Striped Sunlight Sound
# overview               The Go-Betweens\r Three studio albums into the...
# popularity                                                           0.6
# poster_path                                                         None
# production_companies                                                  []
# production_countries                                                  []
# release_date                                                  2005-11-26
# revenue                                                                0
# runtime                                                                0
# spoken_languages                                                      []
# status                                                          Released
# tagline                                                  The Go-Betweens
# title                                        That Striped Sunlight Sound
# video                                                                  0
# vote_average                                                           0
# vote_count                                                             0
# credits                                         {'cast': [], 'crew': []}
# reviews                {'page': 1, 'results': [], 'total_pages': 0, '...

# %%
df_300k.tail()
# Out:
#        adult                     backdrop_path belongs_to_collection  \
# 99995    0.0                              None                  None
# 99996    0.0  /2LWBbV66Dr1lmj36fQK9YzxfEyo.jpg                  None
# 99997    0.0  /j0uiRKL1PRurutFtI0Gut8In2lj.jpg                  None
# 99998    0.0                              None                  None
# 99999    0.0                              None                  None
#
#          budget                                             genres  \
# 99995       0.0                                                 []
# 99996       0.0                     [{'id': 35, 'name': 'Comedy'}]
# 99997  100000.0                      [{'id': 18, 'name': 'Drama'}]
# 99998       0.0                                                 []
# 99999       0.0  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
#
#                                                 homepage        id    imdb_id  \
# 99995                                               None  299996.0       None
# 99996                                                     299997.0       None
# 99997  http://www.maverickentertainment.cc/movies/mov...  299998.0  tt2739792
# 99998                                               None  299999.0  tt3087026
# 99999                                               None  300000.0  tt0091711
#
#       original_language                      original_title  ... runtime  \
# 99995                en                              Athena  ...     NaN
# 99996                en  Bill Santiago: Pardon My Spanglish  ...     0.0
# 99997                en                  Watch Phoenix Rise  ...    90.0
# 99998                en                  What We Can't Have  ...     NaN
# 99999                en                           Overnight  ...    96.0
#
#                                spoken_languages    status  \
# 99995                                        []  Released
# 99996                                        []  Released
# 99997  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 99998                                        []  Released
# 99999  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                       tagline                               title video  \
# 99995                                                      Athena   0.0
# 99996                          Bill Santiago: Pardon My Spanglish   0.0
# 99997  Fame Has Its Downsides                  Watch Phoenix Rise   0.0
# 99998                                          What We Can't Have   0.0
# 99999                                                   Overnight   0.0
#
#        vote_average  vote_count  \
# 99995           0.0         0.0
# 99996           0.0         0.0
# 99997           0.0         0.0
# 99998           0.0         0.0
# 99999           7.0         1.0
#
#                                                  credits  \
# 99995                           {'cast': [], 'crew': []}
# 99996                           {'cast': [], 'crew': []}
# 99997  {'cast': [{'cast_id': 0, 'character': 'Phoenix...
# 99998                           {'cast': [], 'crew': []}
# 99999  {'cast': [{'cast_id': 0, 'character': 'Scott L...
#
#                                                  reviews
# 99995  {'page': 1, 'results': [], 'total_pages': 0, '...
# 99996  {'page': 1, 'results': [], 'total_pages': 0, '...
# 99997  {'page': 1, 'results': [], 'total_pages': 0, '...
# 99998  {'page': 1, 'results': [], 'total_pages': 0, '...
# 99999  {'page': 1, 'results': [], 'total_pages': 0, '...
#
# [5 rows x 27 columns]

# %%
df = pd.DataFrame(get_movies(num=400000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  87751 non-null  object
#  1   backdrop_path          9189 non-null   object
#  2   belongs_to_collection  1384 non-null   object
#  3   budget                 87751 non-null  float64
#  4   genres                 87751 non-null  object
#  5   homepage               59405 non-null  object
#  6   id                     87751 non-null  float64
#  7   imdb_id                72977 non-null  object
#  8   original_language      87751 non-null  object
#  9   original_title         87751 non-null  object
#  10  overview               87751 non-null  object
#  11  popularity             87751 non-null  float64
#  12  poster_path            25581 non-null  object
#  13  production_companies   87751 non-null  object
#  14  production_countries   87751 non-null  object
#  15  release_date           87751 non-null  object
#  16  revenue                87751 non-null  float64
#  17  runtime                71104 non-null  float64
#  18  spoken_languages       87751 non-null  object
#  19  status                 87751 non-null  object
#  20  tagline                87751 non-null  object
#  21  title                  87751 non-null  object
#  22  video                  87751 non-null  object
#  23  vote_average           87751 non-null  float64
#  24  vote_count             87751 non-null  float64
#  25  credits                87751 non-null  object
#  26  reviews                87751 non-null  object
# dtypes: float64(7), object(20)
# memory usage: 20.6+ MB

# %%
#df.to_json('tmdb_movies_400k.json')

# %%
df_400k = pd.read_json('tmdb_movies_400k.json')
df_400k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  87751 non-null  float64
#  1   backdrop_path          9189 non-null   object
#  2   belongs_to_collection  1384 non-null   object
#  3   budget                 87751 non-null  float64
#  4   genres                 87751 non-null  object
#  5   homepage               59405 non-null  object
#  6   id                     87751 non-null  float64
#  7   imdb_id                72977 non-null  object
#  8   original_language      87751 non-null  object
#  9   original_title         87751 non-null  object
#  10  overview               87751 non-null  object
#  11  popularity             87751 non-null  float64
#  12  poster_path            25581 non-null  object
#  13  production_companies   87751 non-null  object
#  14  production_countries   87751 non-null  object
#  15  release_date           87751 non-null  object
#  16  revenue                87751 non-null  float64
#  17  runtime                71104 non-null  float64
#  18  spoken_languages       87751 non-null  object
#  19  status                 87751 non-null  object
#  20  tagline                87751 non-null  object
#  21  title                  87751 non-null  object
#  22  video                  87751 non-null  float64
#  23  vote_average           87751 non-null  float64
#  24  vote_count             87751 non-null  float64
#  25  credits                87751 non-null  object
#  26  reviews                87751 non-null  object
# dtypes: float64(9), object(18)
# memory usage: 21.4+ MB

# %%
df_400k.head().transpose()
# Out:
#                                                                        0  \
# adult                                                                  0
# backdrop_path                                                       None
# belongs_to_collection                                               None
# budget                                                                 0
# genres                                                                []
# homepage                                                            None
# id                                                                300001
# imdb_id
# original_language                                                     en
# original_title                             Blackhawk: Greatest Hits Live
# overview               A spectacular multimedia concert experience fr...
# popularity                                                           0.6
# poster_path                                                         None
# production_companies                                                  []
# production_countries                                                  []
# release_date                                                  2010-01-01
# revenue                                                                0
# runtime                                                               51
# spoken_languages                                                      []
# status                                                          Released
# tagline
# title                                      Blackhawk: Greatest Hits Live
# video                                                                  1
# vote_average                                                           0
# vote_count                                                             0
# credits                                         {'cast': [], 'crew': []}
# reviews                {'page': 1, 'results': [], 'total_pages': 0, '...
#
#                           1  \
# adult                   NaN
# backdrop_path          None
# belongs_to_collection  None
# budget                  NaN
# genres                 None
# homepage               None
# id                      NaN
# imdb_id                None
# original_language      None
# original_title         None
# overview               None
# popularity              NaN
# poster_path            None
# production_companies   None
# production_countries   None
# release_date           None
# revenue                 NaN
# runtime                 NaN
# spoken_languages       None
# status                 None
# tagline                None
# title                  None
# video                   NaN
# vote_average            NaN
# vote_count              NaN
# credits                None
# reviews                None
#
#                                                                        2  \
# adult                                                                  0
# backdrop_path                                                       None
# belongs_to_collection                                               None
# budget                                                                 0
# genres                 [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# homepage
# id                                                                300003
# imdb_id                                                        tt3066658
# original_language                                                     en
# original_title                                              Wild Justice
# overview               An ex-military man Daniel Wilson and his wife ...
# popularity                                                           0.6
# poster_path                                                         None
# production_companies                                                  []
# production_countries                                                  []
# release_date                                                  2014-06-27
# revenue                                                                0
# runtime                                                               84
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline
# title                                                       Wild Justice
# video                                                                  0
# vote_average                                                           0
# vote_count                                                             0
# credits                                         {'cast': [], 'crew': []}
# reviews                {'page': 1, 'results': [], 'total_pages': 0, '...
#
#                                                                        3  \
# adult                                                                  0
# backdrop_path                                                       None
# belongs_to_collection                                               None
# budget                                                                 0
# genres                                                                []
# homepage                                                            None
# id                                                                300004
# imdb_id                                                        tt2750628
# original_language                                                     en
# original_title                                      What Is New Thought?
# overview               From the self-help industry to Alcoholics Anon...
# popularity                                                           0.6
# poster_path                                                         None
# production_companies                                                  []
# production_countries                                                  []
# release_date                                                  2014-03-11
# revenue                                                                0
# runtime                                                              NaN
# spoken_languages                                                      []
# status                                                          Released
# tagline
# title                                               What Is New Thought?
# video                                                                  0
# vote_average                                                           0
# vote_count                                                             0
# credits                                         {'cast': [], 'crew': []}
# reviews                {'page': 1, 'results': [], 'total_pages': 0, '...
#
#                                                                        4
# adult                                                                  0
# backdrop_path                                                       None
# belongs_to_collection                                               None
# budget                                                                 0
# genres                                                                []
# homepage                                                            None
# id                                                                300005
# imdb_id                                                             None
# original_language                                                     en
# original_title                                             Born this Way
# overview               Frost, teen girl on the outside of the "cool" ...
# popularity                                                           0.6
# poster_path                                                         None
# production_companies                                                  []
# production_countries                                                  []
# release_date                                                  2014-01-01
# revenue                                                                0
# runtime                                                              NaN
# spoken_languages                                                      []
# status                                                          Released
# tagline
# title                                                      Born this Way
# video                                                                  0
# vote_average                                                           0
# vote_count                                                             0
# credits                                         {'cast': [], 'crew': []}
# reviews                {'page': 1, 'results': [], 'total_pages': 0, '...

# %%
df_400k.tail()
# Out:
#        adult                     backdrop_path belongs_to_collection  budget  \
# 99995    NaN                              None                  None     NaN
# 99996    0.0                              None                  None     0.0
# 99997    0.0                              None                  None     0.0
# 99998    0.0  /lWk7kaz6iFYYfWiSAHxcVPOvS2Z.jpg                  None     0.0
# 99999    0.0                              None                  None     0.0
#
#                                                   genres homepage        id  \
# 99995                                               None     None       NaN
# 99996  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...           399997.0
# 99997                  [{'id': 10751, 'name': 'Family'}]           399998.0
# 99998                                                 []           399999.0
# 99999                  [{'id': 10751, 'name': 'Family'}]           400000.0
#
#          imdb_id original_language             original_title  ... runtime  \
# 99995       None              None                       None  ...     NaN
# 99996  tt5530520                en                Kate & Lily  ...    15.0
# 99997  tt0763361                en            Mauro the Gypsy  ...    57.0
# 99998       None                en  The Mine and the Minotaur  ...    59.0
# 99999  tt0247526                en                   Mischief  ...    57.0
#
#                                spoken_languages    status tagline  \
# 99995                                      None      None    None
# 99996  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 99997  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 99998                                        []  Released
# 99999                                        []  Released
#
#                            title video  vote_average  vote_count  \
# 99995                       None   NaN           NaN         NaN
# 99996                Kate & Lily   0.0           0.0         0.0
# 99997            Mauro the Gypsy   0.0           0.0         0.0
# 99998  The Mine and the Minotaur   0.0           0.0         0.0
# 99999                   Mischief   0.0           0.0         0.0
#
#                                                  credits  \
# 99995                                               None
# 99996  {'cast': [{'cast_id': 3, 'character': 'Kate', ...
# 99997  {'cast': [{'cast_id': 1, 'character': '', 'cre...
# 99998  {'cast': [{'cast_id': 0, 'character': '', 'cre...
# 99999  {'cast': [{'cast_id': 0, 'character': '', 'cre...
#
#                                                  reviews
# 99995                                               None
# 99996  {'page': 1, 'results': [], 'total_pages': 0, '...
# 99997  {'page': 1, 'results': [], 'total_pages': 0, '...
# 99998  {'page': 1, 'results': [], 'total_pages': 0, '...
# 99999  {'page': 1, 'results': [], 'total_pages': 0, '...
#
# [5 rows x 27 columns]

# %%
df = pd.DataFrame(get_movies(num=500000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  85963 non-null  object
#  1   backdrop_path          18199 non-null  object
#  2   belongs_to_collection  1312 non-null   object
#  3   budget                 85963 non-null  float64
#  4   genres                 85963 non-null  object
#  5   homepage               39202 non-null  object
#  6   id                     85963 non-null  float64
#  7   imdb_id                65495 non-null  object
#  8   original_language      85963 non-null  object
#  9   original_title         85963 non-null  object
#  10  overview               85963 non-null  object
#  11  popularity             85963 non-null  float64
#  12  poster_path            49978 non-null  object
#  13  production_companies   85963 non-null  object
#  14  production_countries   85963 non-null  object
#  15  release_date           85963 non-null  object
#  16  revenue                85963 non-null  float64
#  17  runtime                72032 non-null  float64
#  18  spoken_languages       85963 non-null  object
#  19  status                 85963 non-null  object
#  20  tagline                85963 non-null  object
#  21  title                  85963 non-null  object
#  22  video                  85963 non-null  object
#  23  vote_average           85963 non-null  float64
#  24  vote_count             85963 non-null  float64
#  25  credits                85963 non-null  object
#  26  reviews                85963 non-null  object
# dtypes: float64(7), object(20)
# memory usage: 20.6+ MB

# %%
#df.to_json('tmdb_movies_500k.json')

# %%
df_500k = pd.read_json('tmdb_movies_500k.json')
df_500k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  85963 non-null  float64
#  1   backdrop_path          18199 non-null  object
#  2   belongs_to_collection  1312 non-null   object
#  3   budget                 85963 non-null  float64
#  4   genres                 85963 non-null  object
#  5   homepage               39202 non-null  object
#  6   id                     85963 non-null  float64
#  7   imdb_id                65495 non-null  object
#  8   original_language      85963 non-null  object
#  9   original_title         85963 non-null  object
#  10  overview               85963 non-null  object
#  11  popularity             85963 non-null  float64
#  12  poster_path            49978 non-null  object
#  13  production_companies   85963 non-null  object
#  14  production_countries   85963 non-null  object
#  15  release_date           85963 non-null  object
#  16  revenue                85963 non-null  float64
#  17  runtime                72032 non-null  float64
#  18  spoken_languages       85963 non-null  object
#  19  status                 85963 non-null  object
#  20  tagline                85963 non-null  object
#  21  title                  85963 non-null  object
#  22  video                  85963 non-null  float64
#  23  vote_average           85963 non-null  float64
#  24  vote_count             85963 non-null  float64
#  25  credits                85963 non-null  object
#  26  reviews                85963 non-null  object
# dtypes: float64(9), object(18)
# memory usage: 21.4+ MB

# %%
df_500k.head().transpose()
# Out:
#                                                                        0  \
# adult                                                                  0
# backdrop_path                                                       None
# belongs_to_collection                                               None
# budget                                                                 0
# genres                                [{'id': 10749, 'name': 'Romance'}]
# homepage               http://sic.conaculta.gob.mx/ficha.php?table=pr...
# id                                                                400001
# imdb_id                                                        tt4145318
# original_language                                                     es
# original_title                                                   Trémulo
# overview               Carlos sweeps and mops the floor of an old-tim...
# popularity                                                         2.166
# poster_path                                                         None
# production_companies   [{'id': 299, 'logo_path': '/elssmtHcogGtF8Gxok...
# production_countries            [{'iso_3166_1': 'MX', 'name': 'Mexico'}]
# release_date                                                  2015-03-08
# revenue                                                                0
# runtime                                                               20
# spoken_languages                [{'iso_639_1': 'es', 'name': 'Español'}]
# status                                                          Released
# tagline
# title                                                            Trémulo
# video                                                                  0
# vote_average                                                         7.3
# vote_count                                                            20
# credits                {'cast': [{'cast_id': 24, 'character': 'Carlos...
# reviews                {'page': 1, 'results': [], 'total_pages': 0, '...
#
#                           1     2     3     4
# adult                   NaN   NaN   NaN   NaN
# backdrop_path          None  None  None  None
# belongs_to_collection  None  None  None  None
# budget                  NaN   NaN   NaN   NaN
# genres                 None  None  None  None
# homepage               None  None  None  None
# id                      NaN   NaN   NaN   NaN
# imdb_id                None  None  None  None
# original_language      None  None  None  None
# original_title         None  None  None  None
# overview               None  None  None  None
# popularity              NaN   NaN   NaN   NaN
# poster_path            None  None  None  None
# production_companies   None  None  None  None
# production_countries   None  None  None  None
# release_date           None  None  None  None
# revenue                 NaN   NaN   NaN   NaN
# runtime                 NaN   NaN   NaN   NaN
# spoken_languages       None  None  None  None
# status                 None  None  None  None
# tagline                None  None  None  None
# title                  None  None  None  None
# video                   NaN   NaN   NaN   NaN
# vote_average            NaN   NaN   NaN   NaN
# vote_count              NaN   NaN   NaN   NaN
# credits                None  None  None  None
# reviews                None  None  None  None

# %%
df_500k.tail()
# Out:
#        adult backdrop_path belongs_to_collection  budget  \
# 99995    0.0          None                  None     0.0
# 99996    0.0          None                  None     0.0
# 99997    0.0          None                  None     0.0
# 99998    0.0          None                  None     0.0
# 99999    0.0          None                  None     0.0
#
#                                                   genres          homepage  \
# 99995  [{'id': 35, 'name': 'Comedy'}, {'id': 28, 'nam...              None
# 99996                     [{'id': 28, 'name': 'Action'}]  http://rwblog.id
# 99997                [{'id': 10770, 'name': 'TV Movie'}]              None
# 99998  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...              None
# 99999                      [{'id': 18, 'name': 'Drama'}]              None
#
#              id    imdb_id original_language           original_title  ...  \
# 99995  499996.0  tt2091247                tl  Bornebol: Special Agent  ...
# 99996  499997.0       None                id       21 Petang Berdarah  ...
# 99997  499998.0  tt0115982                en       Crossing the Floor  ...
# 99998  499999.0       None                id                   Bombe'  ...
# 99999  500000.0       None                id  Bombe’ 2: Dumba’-Dumba’  ...
#
#       runtime                                   spoken_languages    status  \
# 99995     NaN                  [{'iso_639_1': 'tl', 'name': ''}]  Released
# 99996    37.0  [{'iso_639_1': 'id', 'name': 'Bahasa indonesia'}]  Released
# 99997    70.0                                                 []  Released
# 99998    92.0  [{'iso_639_1': 'id', 'name': 'Bahasa indonesia'}]  Released
# 99999    90.0  [{'iso_639_1': 'id', 'name': 'Bahasa indonesia'}]  Released
#
#       tagline                    title video  vote_average  vote_count  \
# 99995          Bornebol: Special Agent   0.0           0.0         0.0
# 99996                   21 Blood Night   0.0           0.0         0.0
# 99997               Crossing the Floor   0.0           6.7         3.0
# 99998                           Bombe'   0.0           0.0         0.0
# 99999          Bombe’ 2: Dumba’-Dumba’   0.0           0.0         0.0
#
#                                                  credits  \
# 99995  {'cast': [{'cast_id': 0, 'character': '', 'cre...
# 99996  {'cast': [{'cast_id': 0, 'character': '', 'cre...
# 99997  {'cast': [{'cast_id': 0, 'character': 'David H...
# 99998  {'cast': [{'cast_id': 0, 'character': '', 'cre...
# 99999  {'cast': [{'cast_id': 3, 'character': '', 'cre...
#
#                                                  reviews
# 99995  {'page': 1, 'results': [], 'total_pages': 0, '...
# 99996  {'page': 1, 'results': [], 'total_pages': 0, '...
# 99997  {'page': 1, 'results': [], 'total_pages': 0, '...
# 99998  {'page': 1, 'results': [], 'total_pages': 0, '...
# 99999  {'page': 1, 'results': [], 'total_pages': 0, '...
#
# [5 rows x 27 columns]

# %%
df = pd.DataFrame(get_movies(num=600000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  88747 non-null  object
#  1   backdrop_path          20530 non-null  object
#  2   belongs_to_collection  709 non-null    object
#  3   budget                 88747 non-null  float64
#  4   genres                 88747 non-null  object
#  5   homepage               19565 non-null  object
#  6   id                     88747 non-null  float64
#  7   imdb_id                53314 non-null  object
#  8   original_language      88747 non-null  object
#  9   original_title         88747 non-null  object
#  10  overview               88747 non-null  object
#  11  popularity             88747 non-null  float64
#  12  poster_path            66597 non-null  object
#  13  production_companies   88747 non-null  object
#  14  production_countries   88747 non-null  object
#  15  release_date           88747 non-null  object
#  16  revenue                88747 non-null  float64
#  17  runtime                65042 non-null  float64
#  18  spoken_languages       88747 non-null  object
#  19  status                 88747 non-null  object
#  20  tagline                88747 non-null  object
#  21  title                  88747 non-null  object
#  22  video                  88747 non-null  object
#  23  vote_average           88747 non-null  float64
#  24  vote_count             88747 non-null  float64
#  25  credits                88747 non-null  object
#  26  reviews                88747 non-null  object
# dtypes: float64(7), object(20)
# memory usage: 20.6+ MB

# %%
#df.to_json('tmdb_movies_600k.json')

# %%
df_600k = pd.read_json('tmdb_movies_600k.json')
df_600k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  88747 non-null  float64
#  1   backdrop_path          20530 non-null  object
#  2   belongs_to_collection  709 non-null    object
#  3   budget                 88747 non-null  float64
#  4   genres                 88747 non-null  object
#  5   homepage               19565 non-null  object
#  6   id                     88747 non-null  float64
#  7   imdb_id                53314 non-null  object
#  8   original_language      88747 non-null  object
#  9   original_title         88747 non-null  object
#  10  overview               88747 non-null  object
#  11  popularity             88747 non-null  float64
#  12  poster_path            66597 non-null  object
#  13  production_companies   88747 non-null  object
#  14  production_countries   88747 non-null  object
#  15  release_date           88747 non-null  object
#  16  revenue                88747 non-null  float64
#  17  runtime                65042 non-null  float64
#  18  spoken_languages       88747 non-null  object
#  19  status                 88747 non-null  object
#  20  tagline                88747 non-null  object
#  21  title                  88747 non-null  object
#  22  video                  88747 non-null  float64
#  23  vote_average           88747 non-null  float64
#  24  vote_count             88747 non-null  float64
#  25  credits                88747 non-null  object
#  26  reviews                88747 non-null  object
# dtypes: float64(9), object(18)
# memory usage: 21.4+ MB

# %%
df_600k.head().transpose()
# Out:
#                           0     1  \
# adult                   NaN   NaN
# backdrop_path          None  None
# belongs_to_collection  None  None
# budget                  NaN   NaN
# genres                 None  None
# homepage               None  None
# id                      NaN   NaN
# imdb_id                None  None
# original_language      None  None
# original_title         None  None
# overview               None  None
# popularity              NaN   NaN
# poster_path            None  None
# production_companies   None  None
# production_countries   None  None
# release_date           None  None
# revenue                 NaN   NaN
# runtime                 NaN   NaN
# spoken_languages       None  None
# status                 None  None
# tagline                None  None
# title                  None  None
# video                   NaN   NaN
# vote_average            NaN   NaN
# vote_count              NaN   NaN
# credits                None  None
# reviews                None  None
#
#                                                                        2  \
# adult                                                                  0
# backdrop_path                           /j1gLGTZx9Jy8TDJpR250IAwp3Gg.jpg
# belongs_to_collection                                               None
# budget                                                                 0
# genres                 [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# homepage                                        https://www.cinemand.co/
# id                                                                500003
# imdb_id                                                        tt7422552
# original_language                                                     en
# original_title                                               Funny Story
# overview               A tragic comedy about a well-intentioned fathe...
# popularity                                                         4.203
# poster_path                             /lThumuZPAop9ztKxOiJ4FmDxjsQ.jpg
# production_companies   [{'id': 88931, 'logo_path': None, 'name': 'Cin...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  2018-01-21
# revenue                                                                0
# runtime                                                               84
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline
# title                                                        Funny Story
# video                                                                  0
# vote_average                                                         6.6
# vote_count                                                            11
# credits                {'cast': [{'cast_id': 0, 'character': 'Waiter'...
# reviews                {'page': 1, 'results': [], 'total_pages': 0, '...
#
#                                                                        3  \
# adult                                                                  0
# backdrop_path                           /9kg7HWZcBvvxf0b7duGVBsaPCyn.jpg
# belongs_to_collection                                               None
# budget                                                                 0
# genres                                                                []
# homepage
# id                                                                500004
# imdb_id                                                        tt5522416
# original_language                                                     tr
# original_title                                           Emicem Hospital
# overview               Selo has been working as a caretaker at the Pr...
# popularity                                                           0.6
# poster_path                             /rxZd1AC3OAMWAxwouKO5P136GQ3.jpg
# production_companies                                                  []
# production_countries                                                  []
# release_date                                                  2016-03-25
# revenue                                                                0
# runtime                                                               92
# spoken_languages                 [{'iso_639_1': 'tr', 'name': 'Türkçe'}]
# status                                                          Released
# tagline                                                           comedy
# title                                                    Emicem Hospital
# video                                                                  0
# vote_average                                                           0
# vote_count                                                             0
# credits                                         {'cast': [], 'crew': []}
# reviews                {'page': 1, 'results': [], 'total_pages': 0, '...
#
#                                                                        4
# adult                                                                  0
# backdrop_path                                                       None
# belongs_to_collection                                               None
# budget                                                                 0
# genres                               [{'id': 99, 'name': 'Documentary'}]
# homepage                                                            None
# id                                                                500005
# imdb_id                                                        tt6507448
# original_language                                                     it
# original_title                                   Io sono Valentina Nappi
# overview
# popularity                                                         1.227
# poster_path                              /pFjZGfHmSS60auUhTUttAuvEz7.jpg
# production_companies                                                  []
# production_countries                                                  []
# release_date                                                  2018-01-01
# revenue                                                                0
# runtime                                                              NaN
# spoken_languages                                                      []
# status                                                          Released
# tagline
# title                                            Io sono Valentina Nappi
# video                                                                  0
# vote_average                                                         5.5
# vote_count                                                             2
# credits                {'cast': [{'cast_id': 0, 'character': '', 'cre...
# reviews                {'page': 1, 'results': [], 'total_pages': 0, '...

# %%
df_600k.tail()
# Out:
#        adult                     backdrop_path belongs_to_collection  budget  \
# 99995    0.0                              None                  None     0.0
# 99996    0.0                              None                  None     0.0
# 99997    0.0                              None                  None     0.0
# 99998    0.0  /iBredN64vmai40N2cNv0FKKz7Fc.jpg                  None     0.0
# 99999    0.0                              None                  None     0.0
#
#                                                   genres  \
# 99995                                                 []
# 99996                                                 []
# 99997                                                 []
# 99998  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 99999                                                 []
#
#                                 homepage        id    imdb_id  \
# 99995              http://prudefilm.com/  599996.0       None
# 99996                               None  599997.0       None
# 99997                               None  599998.0       None
# 99998                                     599999.0  tt6198058
# 99999  http://www.taliashealevin.com/eta  600000.0       None
#
#       original_language    original_title  ... runtime  \
# 99995                en             Prude  ...    10.0
# 99996                en      Σουτζουκάκια  ...    15.0
# 99997                zh  Block and Censor  ...    65.0
# 99998                en   Into the Mirror  ...    65.0
# 99999                en             E T A  ...     5.0
#
#                                 spoken_languages    status tagline  \
# 99995   [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 99996  [{'iso_639_1': 'el', 'name': 'ελληνικά'}]  Released
# 99997                                         []  Released
# 99998                                         []  Released
# 99999                                         []  Released
#
#                   title video  vote_average  vote_count  \
# 99995             Prude   0.0           0.0         0.0
# 99996         Meatballs   0.0           0.0         0.0
# 99997  Block and Censor   0.0           0.0         0.0
# 99998   Into the Mirror   0.0           3.0         3.0
# 99999             E T A   0.0           0.0         0.0
#
#                                                  credits  \
# 99995  {'cast': [{'cast_id': 4, 'character': 'Violet'...
# 99996  {'cast': [{'cast_id': 1, 'character': '', 'cre...
# 99997  {'cast': [], 'crew': [{'credit_id': '5ccde6b90...
# 99998  {'cast': [{'cast_id': 2, 'character': 'Daniel'...
# 99999  {'cast': [{'cast_id': 3, 'character': '', 'cre...
#
#                                                  reviews
# 99995  {'page': 1, 'results': [], 'total_pages': 0, '...
# 99996  {'page': 1, 'results': [], 'total_pages': 0, '...
# 99997  {'page': 1, 'results': [], 'total_pages': 0, '...
# 99998  {'page': 1, 'results': [], 'total_pages': 0, '...
# 99999  {'page': 1, 'results': [], 'total_pages': 0, '...
#
# [5 rows x 27 columns]

# %%
df = pd.DataFrame(get_movies(num=700000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  90827 non-null  object
#  1   backdrop_path          16387 non-null  object
#  2   belongs_to_collection  478 non-null    object
#  3   budget                 90827 non-null  float64
#  4   genres                 90827 non-null  object
#  5   homepage               51683 non-null  object
#  6   id                     90827 non-null  float64
#  7   imdb_id                44196 non-null  object
#  8   original_language      90827 non-null  object
#  9   original_title         90827 non-null  object
#  10  overview               90827 non-null  object
#  11  popularity             90827 non-null  float64
#  12  poster_path            62820 non-null  object
#  13  production_companies   90827 non-null  object
#  14  production_countries   90827 non-null  object
#  15  release_date           90827 non-null  object
#  16  revenue                90827 non-null  float64
#  17  runtime                78177 non-null  float64
#  18  spoken_languages       90827 non-null  object
#  19  status                 90827 non-null  object
#  20  tagline                90827 non-null  object
#  21  title                  90827 non-null  object
#  22  video                  90827 non-null  object
#  23  vote_average           90827 non-null  float64
#  24  vote_count             90827 non-null  float64
#  25  credits                90827 non-null  object
#  26  reviews                90827 non-null  object
# dtypes: float64(7), object(20)
# memory usage: 20.6+ MB

# %%
#df.to_json('tmdb_movies_700k.json')

# %%
df_700k = pd.read_json('tmdb_movies_700k.json')
df_700k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  90827 non-null  float64
#  1   backdrop_path          16387 non-null  object
#  2   belongs_to_collection  478 non-null    object
#  3   budget                 90827 non-null  float64
#  4   genres                 90827 non-null  object
#  5   homepage               51683 non-null  object
#  6   id                     90827 non-null  float64
#  7   imdb_id                44196 non-null  object
#  8   original_language      90827 non-null  object
#  9   original_title         90827 non-null  object
#  10  overview               90827 non-null  object
#  11  popularity             90827 non-null  float64
#  12  poster_path            62820 non-null  object
#  13  production_companies   90827 non-null  object
#  14  production_countries   90827 non-null  object
#  15  release_date           90827 non-null  object
#  16  revenue                90827 non-null  float64
#  17  runtime                78177 non-null  float64
#  18  spoken_languages       90827 non-null  object
#  19  status                 90827 non-null  object
#  20  tagline                90827 non-null  object
#  21  title                  90827 non-null  object
#  22  video                  90827 non-null  float64
#  23  vote_average           90827 non-null  float64
#  24  vote_count             90827 non-null  float64
#  25  credits                90827 non-null  object
#  26  reviews                90827 non-null  object
# dtypes: float64(9), object(18)
# memory usage: 21.4+ MB

# %%
df_700k.head().transpose()
# Out:
#                                                                        0  \
# adult                                                                  0
# backdrop_path                                                       None
# belongs_to_collection                                               None
# budget                                                                 0
# genres                                                                []
# homepage                                                            None
# id                                                                600001
# imdb_id                                                        tt2750132
# original_language                                                     de
# original_title                                                    Claire
# overview               On her first night in Berlin, a young woman ga...
# popularity                                                           0.6
# poster_path                                                         None
# production_companies                                                  []
# production_countries   [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...
# release_date                                                  2014-04-18
# revenue                                                                0
# runtime                                                               14
# spoken_languages                [{'iso_639_1': 'de', 'name': 'Deutsch'}]
# status                                                          Released
# tagline
# title                                                             Claire
# video                                                                  0
# vote_average                                                           0
# vote_count                                                             0
# credits                {'cast': [{'cast_id': 1, 'character': 'Claire'...
# reviews                {'page': 1, 'results': [], 'total_pages': 0, '...
#
#                           1     2     3     4
# adult                   NaN   NaN   NaN   NaN
# backdrop_path          None  None  None  None
# belongs_to_collection  None  None  None  None
# budget                  NaN   NaN   NaN   NaN
# genres                 None  None  None  None
# homepage               None  None  None  None
# id                      NaN   NaN   NaN   NaN
# imdb_id                None  None  None  None
# original_language      None  None  None  None
# original_title         None  None  None  None
# overview               None  None  None  None
# popularity              NaN   NaN   NaN   NaN
# poster_path            None  None  None  None
# production_companies   None  None  None  None
# production_countries   None  None  None  None
# release_date           None  None  None  None
# revenue                 NaN   NaN   NaN   NaN
# runtime                 NaN   NaN   NaN   NaN
# spoken_languages       None  None  None  None
# status                 None  None  None  None
# tagline                None  None  None  None
# title                  None  None  None  None
# video                   NaN   NaN   NaN   NaN
# vote_average            NaN   NaN   NaN   NaN
# vote_count              NaN   NaN   NaN   NaN
# credits                None  None  None  None
# reviews                None  None  None  None

# %%
df_700k.tail()
# Out:
#        adult backdrop_path belongs_to_collection  budget genres  \
# 99995    0.0          None                  None     0.0     []
# 99996    0.0          None                  None     0.0     []
# 99997    0.0          None                  None     0.0     []
# 99998    0.0          None                  None     0.0     []
# 99999    0.0          None                  None     0.0     []
#
#                          homepage        id     imdb_id original_language  \
# 99995  https://www.yesterway.org/  699996.0        None                en
# 99996                              699997.0   tt4420000                en
# 99997                              699998.0  tt11872724                es
# 99998                              699999.0   tt0324364                fr
# 99999                              700000.0        None                fr
#
#                                        original_title  ... runtime  \
# 99995                                       Yesterway  ...   107.0
# 99996                                        Kalopsia  ...    12.0
# 99997                               Poderoso Victoria  ...     0.0
# 99998  Is Dead - Portrait incomplet de Gertrude Stein  ...    47.0
# 99999                                    Degas et moi  ...    20.0
#
#                                spoken_languages           status tagline  \
# 99995                                        []         Released
# 99996                                        []         Released
# 99997  [{'iso_639_1': 'es', 'name': 'Español'}]  Post Production
# 99998                                        []         Released
# 99999                                        []         Released
#
#                                                 title video  vote_average  \
# 99995                                       Yesterway   0.0           0.0
# 99996                                        Kalopsia   0.0           0.0
# 99997                                 Mighty Victoria   0.0           0.0
# 99998  Is Dead - Portrait incomplet de Gertrude Stein   0.0           0.0
# 99999                                    Degas et moi   0.0           0.0
#
#        vote_count                                            credits  \
# 99995         0.0  {'cast': [], 'crew': [{'credit_id': '5eaef39d0...
# 99996         0.0  {'cast': [{'cast_id': 1, 'character': 'Alice',...
# 99997         0.0  {'cast': [{'cast_id': 7, 'character': 'Don Fed...
# 99998         0.0  {'cast': [{'cast_id': 1, 'character': '', 'cre...
# 99999         0.0  {'cast': [{'cast_id': 2, 'character': '', 'cre...
#
#                                                  reviews
# 99995  {'page': 1, 'results': [], 'total_pages': 0, '...
# 99996  {'page': 1, 'results': [], 'total_pages': 0, '...
# 99997  {'page': 1, 'results': [], 'total_pages': 0, '...
# 99998  {'page': 1, 'results': [], 'total_pages': 0, '...
# 99999  {'page': 1, 'results': [], 'total_pages': 0, '...
#
# [5 rows x 27 columns]

# %%
df = pd.DataFrame(get_movies(num=800000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  1592 non-null   object
#  1   backdrop_path          206 non-null    object
#  2   belongs_to_collection  14 non-null     object
#  3   budget                 1592 non-null   float64
#  4   genres                 1592 non-null   object
#  5   homepage               1592 non-null   object
#  6   id                     1592 non-null   float64
#  7   imdb_id                627 non-null    object
#  8   original_language      1592 non-null   object
#  9   original_title         1592 non-null   object
#  10  overview               1592 non-null   object
#  11  popularity             1592 non-null   float64
#  12  poster_path            846 non-null    object
#  13  production_companies   1592 non-null   object
#  14  production_countries   1592 non-null   object
#  15  release_date           1592 non-null   object
#  16  revenue                1592 non-null   float64
#  17  runtime                1592 non-null   float64
#  18  spoken_languages       1592 non-null   object
#  19  status                 1592 non-null   object
#  20  tagline                1592 non-null   object
#  21  title                  1592 non-null   object
#  22  video                  1592 non-null   object
#  23  vote_average           1592 non-null   float64
#  24  vote_count             1592 non-null   float64
#  25  credits                1592 non-null   object
#  26  reviews                1591 non-null   object
# dtypes: float64(7), object(20)
# memory usage: 20.6+ MB

# %%
#df.to_json('tmdb_movies_800k.json')

# %%
df_800k = pd.read_json('tmdb_movies_800k.json')
df_800k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  1592 non-null   float64
#  1   backdrop_path          206 non-null    object
#  2   belongs_to_collection  14 non-null     object
#  3   budget                 1592 non-null   float64
#  4   genres                 1592 non-null   object
#  5   homepage               1592 non-null   object
#  6   id                     1592 non-null   float64
#  7   imdb_id                627 non-null    object
#  8   original_language      1592 non-null   object
#  9   original_title         1592 non-null   object
#  10  overview               1592 non-null   object
#  11  popularity             1592 non-null   float64
#  12  poster_path            846 non-null    object
#  13  production_companies   1592 non-null   object
#  14  production_countries   1592 non-null   object
#  15  release_date           1592 non-null   object
#  16  revenue                1592 non-null   float64
#  17  runtime                1592 non-null   float64
#  18  spoken_languages       1592 non-null   object
#  19  status                 1592 non-null   object
#  20  tagline                1592 non-null   object
#  21  title                  1592 non-null   object
#  22  video                  1592 non-null   float64
#  23  vote_average           1592 non-null   float64
#  24  vote_count             1592 non-null   float64
#  25  credits                1592 non-null   object
#  26  reviews                1591 non-null   object
# dtypes: float64(9), object(18)
# memory usage: 21.4+ MB

# %%
df_800k.head().transpose()
# Out:
#                                                                        0  \
# adult                                                                  0
# backdrop_path                                                       None
# belongs_to_collection                                               None
# budget                                                                 0
# genres                 [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# homepage
# id                                                                700001
# imdb_id                                                        tt0279235
# original_language                                                     cs
# original_title                                            Mnichovo srdce
# overview
# popularity                                                           0.6
# poster_path                                                         None
# production_companies   [{'id': 133230, 'logo_path': None, 'name': 'Th...
# production_countries    [{'iso_3166_1': 'XC', 'name': 'Czechoslovakia'}]
# release_date                                                  1921-09-16
# revenue                                                                0
# runtime                                                                0
# spoken_languages            [{'iso_639_1': 'xx', 'name': 'No Language'}]
# status                                                          Released
# tagline
# title                                                     Mnichovo srdce
# video                                                                  0
# vote_average                                                           0
# vote_count                                                             0
# credits                {'cast': [{'cast_id': 1, 'character': '', 'cre...
# reviews                {'page': 1, 'results': [], 'total_pages': 0, '...
#
#                                                                        1  \
# adult                                                                  0
# backdrop_path                                                       None
# belongs_to_collection                                               None
# budget                                                                 0
# genres                                                                []
# homepage
# id                                                                700002
# imdb_id                                                             None
# original_language                                                     es
# original_title                             Chancho en Piedra - Chancho 6
# overview
# popularity                                                           0.6
# poster_path                             /4JlyHIfimGnc3v5rHXuliIUPqgW.jpg
# production_companies                                                  []
# production_countries                                                  []
# release_date
# revenue                                                                0
# runtime                                                                0
# spoken_languages                                                      []
# status                                                          Released
# tagline
# title                                      Chancho en Piedra - Chancho 6
# video                                                                  1
# vote_average                                                           0
# vote_count                                                             0
# credits                                         {'cast': [], 'crew': []}
# reviews                {'page': 1, 'results': [], 'total_pages': 0, '...
#
#                                                                        2  \
# adult                                                                  0
# backdrop_path                                                       None
# belongs_to_collection                                               None
# budget                                                                 0
# genres                 [{'id': 35, 'name': 'Comedy'}, {'id': 12, 'nam...
# homepage
# id                                                                700003
# imdb_id                                                             None
# original_language                                                     en
# original_title                                        Who Stole My Sofa?
# overview               Ashens looses his sofa and is on a quest to ge...
# popularity                                                           0.6
# poster_path                             /7RE9w3jUfUnbZGkIKdj8tEU9nyY.jpg
# production_companies                                                  []
# production_countries                                                  []
# release_date                                                  2014-08-14
# revenue                                                                0
# runtime                                                               27
# spoken_languages                                                      []
# status                                                          Released
# tagline
# title                                                 Who Stole My Sofa?
# video                                                                  0
# vote_average                                                           0
# vote_count                                                             0
# credits                {'cast': [{'cast_id': 1, 'character': 'Himself...
# reviews                {'page': 1, 'results': [], 'total_pages': 0, '...
#
#                           3                                                  4
# adult                   NaN                                                  0
# backdrop_path          None                                               None
# belongs_to_collection  None                                               None
# budget                  NaN                                                  0
# genres                 None                [{'id': 99, 'name': 'Documentary'}]
# homepage               None
# id                      NaN                                             700005
# imdb_id                None                                               None
# original_language      None                                                 en
# original_title         None                                 Birds of a Feather
# overview               None  In Birds of a Feather, Nora Sweeney creates a ...
# popularity              NaN                                              4.212
# poster_path            None                   /zC1V0rGSCIWRxNuRUdopDJmqtBi.jpg
# production_companies   None                                                 []
# production_countries   None  [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date           None                                         2020-05-03
# revenue                 NaN                                                  0
# runtime                 NaN                                                 19
# spoken_languages       None                  [{'iso_639_1': 'hy', 'name': ''}]
# status                 None                                           Released
# tagline                None
# title                  None                                 Birds of a Feather
# video                   NaN                                                  0
# vote_average            NaN                                                  0
# vote_count              NaN                                                  0
# credits                None  {'cast': [], 'crew': [{'credit_id': '5eaef93b0...
# reviews                None  {'page': 1, 'results': [], 'total_pages': 0, '...

# %%
df_800k.tail()
# Out:
#        adult backdrop_path belongs_to_collection  budget genres homepage  id  \
# 99995    NaN          None                  None     NaN   None     None NaN
# 99996    NaN          None                  None     NaN   None     None NaN
# 99997    NaN          None                  None     NaN   None     None NaN
# 99998    NaN          None                  None     NaN   None     None NaN
# 99999    NaN          None                  None     NaN   None     None NaN
#
#       imdb_id original_language original_title  ... runtime  spoken_languages  \
# 99995    None              None           None  ...     NaN              None
# 99996    None              None           None  ...     NaN              None
# 99997    None              None           None  ...     NaN              None
# 99998    None              None           None  ...     NaN              None
# 99999    None              None           None  ...     NaN              None
#
#       status tagline title video  vote_average  vote_count credits reviews
# 99995   None    None  None   NaN           NaN         NaN    None    None
# 99996   None    None  None   NaN           NaN         NaN    None    None
# 99997   None    None  None   NaN           NaN         NaN    None    None
# 99998   None    None  None   NaN           NaN         NaN    None    None
# 99999   None    None  None   NaN           NaN         NaN    None    None
#
# [5 rows x 27 columns]

# %%
raise SystemExit("Stop right there!")
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Stop right there!
# /home/lord_black/anaconda3/envs/movieCap1/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# latest = 701125
